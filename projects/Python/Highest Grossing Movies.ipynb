# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df=pd.read_csv(r'C:\Users\Jegadeesh\Downloads\Compressed\Projects\Highest Holywood Grossing Movies.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Star Wars: Episode VII - The Force Awakens (2015)
# 1           1                           Avengers: Endgame (2019)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
#
#                            Distributor       Release Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
#
#    Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 0              936662225                  1132859475          2069521700
# 1              858373000                  1939128328          2797501328
#
#                                         Genre Movie Runtime License
# 0           ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# ...

# %% [raw]
# Rename Unnamed Column

# %%
df.rename(columns={'Unnamed: 0':'Index'},inplace=True)

# %%
df.head(2)
# Out:
#    Index                                              Title  \
# 0      0  Star Wars: Episode VII - The Force Awakens (2015)
# 1      1                           Avengers: Endgame (2019)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
#
#                            Distributor       Release Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
#
#    Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 0              936662225                  1132859475          2069521700
# 1              858373000                  1939128328          2797501328
#
#                                         Genre Movie Runtime License
# 0           ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# 1  ['Action', 'Adventure', 'Drama', 'Sci-Fi']    3 hr 1 min   PG-13

# %% [raw]
# Set Index Column as Index

# %%
df.set_index('Index',inplace=True)

# %%
df.head(2)
# Out:
#                                                    Title  \
# Index
# 0      Star Wars: Episode VII - The Force Awakens (2015)
# 1                               Avengers: Endgame (2019)
#
#                                               Movie Info  \
# Index
# 0      As a new threat to the galaxy rises, Rey, a de...
# 1      After the devastating events of Avengers: Infi...
#
#                                Distributor       Release Date  \
# Index
# 0      Walt Disney Studios Motion Pictures  December 16, 2015
# 1      Walt Disney Studios Motion Pictures     April 24, 2019
#
#        Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# Index
# 0                  936662225                  1132859475          2069521700
# 1                  858373000                  1939128328          2797501328
#
#                                             Genre Movie Runtime License
# Index
# 0               ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min   PG-13
# ...

# %%
df.describe()
# Out:
#        Domestic Sales (in $)  International Sales (in $)  World Sales (in $)
# count                918.000                     918.000             918.000
# mean           167746917.939               230143435.585       396866825.782
# std            104036044.970               217601104.217       308262916.044
# min             80360843.000                     260.000        81600000.000
# 25%            101607071.750                88456200.250       200556355.250
# 50%            132135096.000               163881928.000       301941607.000
# 75%            191390485.500               288557651.000       475071823.500
# max            936662225.000              2086738578.000      2847246203.000

# %%
def to_million(x):
    return x/1000000
item=["Domestic Sales (in $)","International Sales (in $)","World Sales (in $)"]
for i in item:
    df[i]=df[i].apply(to_million)

# %% [raw]
# Rename Columns to make it Million

# %%
df.rename(columns={'Domestic Sales (in $)':'Domestic Sales (in $M)','International Sales (in $)':'International Sales (in $M)','World Sales (in $)':'World Sales (in $M)'},inplace=True)

# %%
df.head()
# Out:
#                                                    Title  \
# Index
# 0      Star Wars: Episode VII - The Force Awakens (2015)
# 1                               Avengers: Endgame (2019)
# 2                                          Avatar (2009)
# 3                                   Black Panther (2018)
# 4                          Avengers: Infinity War (2018)
#
#                                               Movie Info  \
# Index
# 0      As a new threat to the galaxy rises, Rey, a de...
# 1      After the devastating events of Avengers: Infi...
# 2      A paraplegic Marine dispatched to the moon Pan...
# 3      T'Challa, heir to the hidden but advanced king...
# 4      The Avengers and their allies must be willing ...
#
#                                Distributor       Release Date  \
# Index
# 0      Walt Disney Studios Motion Pictures  December 16, 2015
# 1      Walt Disney Studios Motion Pictures     April 24, 2019
# ...

# %% [raw]
# Find Null Values

# %%
df.isnull().sum()
# Out:
# Title                            0
# Movie Info                       0
# Distributor                      0
# Release Date                   118
# Domestic Sales (in $M)           0
# International Sales (in $M)      0
# World Sales (in $M)              0
# Genre                            0
# Movie Runtime                    0
# License                        174
# dtype: int64

# %%
df[df['Release Date'].isnull()]
# Out:
#                                 Title  \
# Index
# 3                Black Panther (2018)
# 4       Avengers: Infinity War (2018)
# 5      Spider-Man: No Way Home (2021)
# 10               Incredibles 2 (2018)
# 16                Finding Dory (2016)
# ...                               ...
# 890     Cheaper by the Dozen 2 (2005)
# 891         Mr. Holland's Opus (1995)
# 896       Bridge to Terabithia (2007)
# 903                       MASH (1970)
# 912                      Congo (1995)
#
#                                               Movie Info  \
# Index
# 3      T'Challa, heir to the hidden but advanced king...
# 4      The Avengers and their allies must be willing ...
# 5      With Spider-Man's identity now revealed, Peter...
# 10     The Incredibles family takes on a new mission ...
# 16     Friendly but forgetful blue tang Dory begins a...
# ...                                                  ...
# 890    The Bakers, while on vacation, find themselves...
# ...

# %%
df.head()
# Out:
#                                                    Title  \
# Index
# 0      Star Wars: Episode VII - The Force Awakens (2015)
# 1                               Avengers: Endgame (2019)
# 2                                          Avatar (2009)
# 3                                   Black Panther (2018)
# 4                          Avengers: Infinity War (2018)
#
#                                               Movie Info  \
# Index
# 0      As a new threat to the galaxy rises, Rey, a de...
# 1      After the devastating events of Avengers: Infi...
# 2      A paraplegic Marine dispatched to the moon Pan...
# 3      T'Challa, heir to the hidden but advanced king...
# 4      The Avengers and their allies must be willing ...
#
#                                Distributor       Release Date  \
# Index
# 0      Walt Disney Studios Motion Pictures  December 16, 2015
# 1      Walt Disney Studios Motion Pictures     April 24, 2019
# ...

# %%
df.dtypes
# Out:
# Title                           object
# Movie Info                      object
# Distributor                     object
# Release Date                    object
# Domestic Sales (in $M)         float64
# International Sales (in $M)    float64
# World Sales (in $M)            float64
# Genre                           object
# Movie Runtime                   object
# License                         object
# dtype: object

# %%
df['Release Date']=pd.to_datetime(df['Release Date'])

# %% [raw]
# Distributor Count

# %%
df['Distributor'].value_counts()
# Out:
# Warner Bros.                           158
# Walt Disney Studios Motion Pictures    155
# Universal Pictures                     119
# Twentieth Century Fox                  117
# Sony Pictures Entertainment (SPE)      101
# Paramount Pictures                      99
# DreamWorks                              21
# New Line Cinema                         21
# Lionsgate                               19
# DreamWorks Distribution                 17
# Metro-Goldwyn-Mayer (MGM)               12
# TriStar Pictures                         9
# Miramax                                  9
# Revolution Studios                       8
# Columbia Pictures                        7
# Dimension Films                          7
# The Weinstein Company                    6
# Summit Entertainment                     5
# Fox Searchlight Pictures                 4
# STX Entertainment                        3
# Orion Pictures                           3
# Screen Gems                              3
# ...

# %% [raw]
# Distributor for top 100 Gross Movies

# %%
df[df.index <=49]
# Out:
#                                                    Title  \
# Index
# 0      Star Wars: Episode VII - The Force Awakens (2015)
# 1                               Avengers: Endgame (2019)
# 2                                          Avatar (2009)
# 3                                   Black Panther (2018)
# 4                          Avengers: Infinity War (2018)
# 5                         Spider-Man: No Way Home (2021)
# 6                                         Titanic (1997)
# 7                                  Jurassic World (2015)
# 8                                    The Avengers (2012)
# 9         Star Wars: Episode VIII - The Last Jedi (2017)
# 10                                  Incredibles 2 (2018)
# 11                                  The Lion King (2019)
# 12                                The Dark Knight (2008)
# 13                   Rogue One: A Star Wars Story (2016)
# 14     Star Wars: Episode IX - The Rise of Skywalker ...
# ...

# %% [raw]
# Value Count for Top 50 by two different Method

# %%
Df2=df[df.index <=49]

# %%
Df2['Distributor'].value_counts()
# Out:
# Walt Disney Studios Motion Pictures    24
# Universal Pictures                      6
# Sony Pictures Entertainment (SPE)       5
# Twentieth Century Fox                   4
# Warner Bros.                            4
# Lionsgate                               2
# Paramount Pictures                      1
# DreamWorks Distribution                 1
# DreamWorks                              1
# New Line Cinema                         1
# Newmarket Films                         1
# Name: Distributor, dtype: int64

# %%
df[df.index <=49].Distributor.value_counts()
# Out:
# Walt Disney Studios Motion Pictures    24
# Universal Pictures                      6
# Sony Pictures Entertainment (SPE)       5
# Twentieth Century Fox                   4
# Warner Bros.                            4
# Lionsgate                               2
# Paramount Pictures                      1
# DreamWorks Distribution                 1
# DreamWorks                              1
# New Line Cinema                         1
# Newmarket Films                         1
# Name: Distributor, dtype: int64

# %% [raw]
# Top 100 Movies Based on Distributor

# %%
df[df.index <=99].Distributor.value_counts()
# Out:
# Walt Disney Studios Motion Pictures    36
# Warner Bros.                           17
# Twentieth Century Fox                  10
# Sony Pictures Entertainment (SPE)       9
# Universal Pictures                      8
# Paramount Pictures                      5
# Lionsgate                               4
# DreamWorks                              4
# New Line Cinema                         3
# Summit Entertainment                    2
# DreamWorks Distribution                 1
# Newmarket Films                         1
# Name: Distributor, dtype: int64

# %%
#Top 100 Movies Gross sum based on Distributor
df2=df[df.index <=99]
df3=df.groupby(['Distributor']).sum()
df3.sort_values(by=['World Sales (in $M)'],ascending=False)
# Out:
#                                      Domestic Sales (in $M)  \
# Distributor
# Walt Disney Studios Motion Pictures               34098.332
# Warner Bros.                                      25891.723
# Twentieth Century Fox                             19114.853
# Universal Pictures                                19316.009
# Sony Pictures Entertainment (SPE)                 15764.875
# Paramount Pictures                                14484.466
# DreamWorks                                         4040.554
# Lionsgate                                          3424.851
# New Line Cinema                                    3454.991
# DreamWorks Distribution                            2728.574
# Metro-Goldwyn-Mayer (MGM)                          1528.265
# Summit Entertainment                               1163.978
# TriStar Pictures                                   1062.086
# Miramax                                            1081.876
# ...

# %%
#Top 100 Movies Gross sum based on Distributor
df[df.index<=99]
# Out:
#                                                    Title  \
# Index
# 0      Star Wars: Episode VII - The Force Awakens (2015)
# 1                               Avengers: Endgame (2019)
# 2                                          Avatar (2009)
# 3                                   Black Panther (2018)
# 4                          Avengers: Infinity War (2018)
# ...                                                  ...
# 95                                      Inception (2010)
# 96      Harry Potter and the Order of the Phoenix (2007)
# 97      The Twilight Saga: Breaking Dawn - Part 2 (2012)
# 98     The Chronicles of Narnia: The Lion, the Witch ...
# 99                                   Man of Steel (2013)
#
#                                               Movie Info  \
# Index
# 0      As a new threat to the galaxy rises, Rey, a de...
# 1      After the devastating events of Avengers: Infi...
# 2      A paraplegic Marine dispatched to the moon Pan...
# ...
